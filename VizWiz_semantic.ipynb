# %%
# %load_ext autoreload
# %autoreload 2

import os
import torch
import numpy as np
from glob import glob
from tqdm.auto import tqdm
from sklearn.linear_model import LogisticRegression
import pandas as pd
from utils.store_data import ReadData
import numpy as np
import torch
from utils.arguments import Arguments
from tqdm import tqdm
from sklearn.decomposition import PCA
from linear_probe import get_linear_acc
import random
import os
from sklearn.metrics import roc_auc_score,accuracy_score,roc_curve
from answer_judge.vqaEval import VQAEval
from ml_utils.semantic_clustering.semantic_clustering import SemanticClustering
from ml_utils.semantic_clustering.semantic_entropy import EntailmentDeberta

# %%
data_reader=ReadData('/root/autodl-tmp/hallscope/VizWiz/multi/train')
data=data_reader.read_all()
random.shuffle(data)

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                                             img_path  \
# 0  [/root/autodl-fs/vizwiz/train/train/VizWiz_tra...
# 1  [/root/autodl-fs/vizwiz/train/train/VizWiz_tra...
# 2  [/root/autodl-fs/vizwiz/train/train/VizWiz_tra...
# 3  [/root/autodl-fs/vizwiz/train/train/VizWiz_tra...
# 4  [/root/autodl-fs/vizwiz/train/train/VizWiz_tra...
#
#                                             question     answer_type  \
# 0  [Given the question 'Can you tell me what this...         [other]
# 1  [Given the question 'What kind of snacks are t...         [other]
# 2  [Given the question 'What is this CD?', is the...         [other]
# 3  [Given the question 'What is the thermostat se...  [unanswerable]
# 4  [Given the question 'What does this page say?'...  [unanswerable]
#
#                                              answers  \
# 0  [{'answer': ['106.9'], 'answer_confidence': ['...
# 1  [{'answer_confidence': ['yes'], 'answer': ['so...
# 2  [{'answer_confidence': ['no'], 'answer': ['not...
# 3  [{'answer_confidence': ['yes'], 'answer': ['69...
# 4  [{'answer_confidence': ['yes'], 'answer': ['un...
#
#                                          most_likely  \
# 0  {'embedding': [[[-0.00073624  0.0111084  -0.01...
# 1  {'embedding': [[[-0.00073624  0.0111084  -0.01...
# 2  {'embedding': [[[-0.00073624  0.0111084  -0.01...
# 3  {'embedding': [[[-0.00073624  0.0111084  -0.01...
# 4  {'embedding': [[[-0.00073624  0.0111084  -0.01...
#
#                                            responses
# 0  [Unanswerable, Answerable., Unanswerable, Answ...
# 1  [Unanswerable, Answerable, Answerable, Unanswe...
# 2  [Unanswerable, Answerable, Unanswerable, Answe...
# 3  [Unanswerable., Unanswerable, Answerable, Unan...
# 4  [Answerable, Unanswerable, Answerable, Unanswe...

# %%
df.shape
# Out:
# (5167, 6)

# %%
i=1

# %%
df.iloc[i]['img_path']
# Out:
# ['/root/autodl-fs/vizwiz/train/train/VizWiz_train_00004886.jpg']

# %%
df.iloc[i]['most_likely']['response']
# Out:
# ['Unanswerable']

# %%
df.iloc[i]['question']
# Out:
# ["Given the question 'What kind of snacks are these?', is the question answerable or unanswerable based on the image?\nPlease reply with 'Unanswerable' or 'Answerable'."]

# %%
df.iloc[i]['responses']
# Out:
# ['Unanswerable',
#  'Answerable',
#  'Answerable',
#  'Unanswerable',
#  'Answerable. The image shows a bowl of popcorn topped with a small red bean, which is a piece of corn kernel. This information allows the question to be answered and understood.',
#  'Unanswerable']

# %%
df.iloc[i]['answer_type']
# Out:
# ['other']

# %%
gt_label=df['answer_type'].to_list()
gt_label=np.concatenate(gt_label,axis=0).tolist()
len(gt_label)
# Out:
# 5167

# %%
responses=df['most_likely'].apply(lambda x: x['response']).to_list()
rsps=[]
for x in responses:
    rsps+=x

# %%
all_responses=df['responses'].to_list()
all_responses
# Out:
# [['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable. The image shows a bowl of popcorn topped with a small red bean, which is a piece of corn kernel. This information allows the question to be answered and understood.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['No.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['UnAnswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable. Since the focus of the image is on the back of the shirt, it is not possible to confidently determine the front of the shirt from this perspective.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable. The image depicts a person holding a piece of paper, but it does not provide enough context to discern the content or message conveyed by the paper.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   "Unanswerable since the focus of the question is on a label on the floor, and there is no concrete reference to the soup's flavor.",
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   "Unlike the pizza itself, which tells about various details like the ingredients, the image does not provide the information related to the oven's temperature or the required minutes for pizza cooking. Therefore, it is unanswerable",
#   'Unanswerable. The image shows that it is a microwaveable pizza, along with instructions for conventional ovens. However, there is no indication of the temperature setting or the amount of time required for conventional oven cooking.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable. The image captures a view of dark clouds outside the car window at night, but the clouds are not distinctly defined as either storm clouds or rain clouds, making it difficult to confidently determine their classification.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'It would not be possible to accurately determine the expiration date of the item in the gray can on the wooden surface, as there is no visible label or indicator of its expiration date.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable. The image shows a box of lasagna and an instruction book which is likely to be the oven instructions for baking it. An instruction book might offer vital details about oven usage, proper placement, cooking and baking'],
#  ['Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   "The question is unanswerable since the image does not provide enough context or information to determine what the object is. It could be a remote control or any other electronic device, but without any distinctive features or text labels, it's not possible",
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable. The image is a view of a floor or ground from a higher view point or angle. This is enough context to provide the answer to the question.',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable, the question seems to be ambiguous or does not have enough context to correctly answer the question based on the image.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable, the image shows a gray fabric background, but it does not provide any specific color or pattern to the viewer.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable, as the image does not contain any information that can help determine the specific kind of yogurt.',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable. The image shows a coffee table with a mug, a paper, a remote, and an Eiffel Tower on it.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable. The image shows the back of a box with a red border labeling the food inside as "Pizza Biscuits". There is also an expiry date on the label.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Response',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'No.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   "Understanding what kind of dog based on the image is difficult due to the pink background and bed obscuring the dog's breed characteristics. Unanswerable.",
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable; the text is not easily legible in the image.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answers the question "What movie is this?" by providing an example.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Yes',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable. The water bottle is either clear or sparkling, and depending on the photo, one can see the bottom portion of the water bottle. Based on the image, the question can be answered if the water is stale or spark',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unaskable.'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Answerable.',
#   'Unanswerable as there is no picture attached to the question.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable.',
#   'Answerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'UNANSWERABLE',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable since the image does not provide any visible content that can be read out, like text or branding, that might help answer the question.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable. The question asks for the type of bottle. There is a clear and simple answer to this question, as it is a milk bottle with a white substance inside.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Answerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable. The color of the dress in the image is not a part of the image description or subject of any description.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable: The question refers to a cloud formation that can be more elusive and subjective than the clear blue sky shown in the image.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable'],
#  ["As the image is close up of hair, a bed, and a blanket, there isn't any clear indication of someone's face being visible or making a face. The image mainly focuses on the hair, bedding and cur",
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable:',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unaskable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable. There are no clock face or any indication that it is a timer with a dial.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable.'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   "Unanswerable'",
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'In answerable.',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'The text "Ojepte!" on the back of the book is printed in Spanish, which is different from the Latin alphabet and may not be readable, or understood, in a non-Spainish-speaking environment.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable. Since the image shows a hand holding the other end of an object with a red and black design, it does not provide information on how that object was turned or adjusted to reveal the expiration date.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
# ...
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable. If you look at the back of the package, it shows that it is from Galaxy Chocolate.'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Understanding the context that a person is describing the nutritional information of the ingredients of the frozen dinner is the best answer so it is answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable, the treadmill is displaying the distance in miles at two miles.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Yes',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable.',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable.'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unclear',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'UNANSWERABLE',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.'],
#  ['Answerable',
#   'Based on the image, the question is answerable. There is a label attached to the bottle with the label description of what is in the bottle.',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable. The image shows a box of food, and there is a written description (possibly a recipe) which provides guidance on how to prepare the microwave oven cooked food.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unaddressable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Unanswerable',
#   "Asking what the paper says is unanswerable based on the provided image description since it is only providing details about the table and not about the paper. This information alone does not enable determining the paper's content, and one would need more",
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable.',
#   'Answerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'The expiration date of this box of food can be identified on the label as it shows the date it was made. However, since the box of food is standing on a table and there is a keyboard in the background, it is likely that the',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable.',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable.',
#   'Answerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Attachments could not be loaded'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Answerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Answerable.',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable.',
#   'Answerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Answerable.',
#   'Unanswerable.',
#   'Unanswerable.'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Answerable.',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable.',
#   'Answerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable',
#   'Answerable',
#   'Unanswerable'],
#  ['Answerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Answerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable',
#   'Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Answerable'],
#  ['Answerable',
#   'Answerable.',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable.',
#   'Unanswerable'],
#  ['Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable',
#   'Unanswerable'],
#  ...]

# %%
len(all_responses)
# Out:
# 5167

# %%
entailment_model=EntailmentDeberta()
cluster=SemanticClustering(entailment_model)
entropies=[]

for i in tqdm(range(len(all_responses))):
    entropies.append(cluster.get_entropy(all_responses[i]))
# Out:
#   0%|          | 7/5167 [00:05<55:04,  1.56it/s]
# model.safetensors:  46%|####6     | 818M/1.77G [00:00<?, ?B/s]
#  26%|██▌       | 1356/5167 [13:56<39:09,  1.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       3 entropies=[]
#       5 for i in tqdm(range(len(all_responses))):
# ----> 6     entropies.append(cluster.get_entropy(all_responses[i]))
#
# File /home/hallscope/ml_utils/semantic_clustering/semantic_clustering.py:14, in SemanticClustering.get_entropy(self, responses, example)
#       9 def get_entropy(self, responses: list[str], example: str = None):
#      10     '''return semantic entropy for one question
#      11     responses: a list that contains different generations for 'example'
#      12     example: one question in input dataset
#      13     '''
# ---> 14     semantic_ids = get_semantic_ids(
#      15         responses, model=self.entailment_model,
#      16         strict_entailment=False, example=example)
#      17     entropy = cluster_assignment_entropy(semantic_ids)
#      18     return entropy
#
# File /home/hallscope/ml_utils/semantic_clustering/semantic_entropy.py:209, in get_semantic_ids(strings_list, model, strict_entailment, example)
#     206 semantic_set_ids[i] = next_id
#     207 for j in range(i+1, len(strings_list)):
#     208     # Search through all remaining strings. If they are equivalent to string1, assign them the same id.
# --> 209     if are_equivalent(string1, strings_list[j]):
#     210         semantic_set_ids[j] = next_id
#     211 next_id += 1
#
# File /home/hallscope/ml_utils/semantic_clustering/semantic_entropy.py:181, in get_semantic_ids.<locals>.are_equivalent(text1, text2)
#     176 def are_equivalent(text1, text2):
#     177     '''0 typically stands for contradiction (text1 does not imply text2).
#     178        1 stands for neutral (no clear implication).
#     179        2 stands for entailment (text1 implies text2).
#     180     '''
# --> 181     implication_1 = model.check_implication(text1, text2, example=example)
#     182     implication_2 = model.check_implication(
#     183         text2, text1, example=example)  # pylint: disable=arguments-out-of-order
#     184     assert (implication_1 in [0, 1, 2]) and (implication_2 in [0, 1, 2])
#
# File /home/hallscope/ml_utils/semantic_clustering/semantic_entropy.py:44, in EntailmentDeberta.check_implication(self, text1, text2, *args, **kwargs)
#      39 inputs = self.tokenizer(
#      40     text1, text2, return_tensors="pt", max_length=200, truncation=True, padding=True).to(DEVICE)
#      41 # The model checks if text1 -> text2, i.e. if text2 follows from text1.
#      42 # check_implication('The weather is good', 'The weather is good and I like you') --> 1
#      43 # check_implication('The weather is good and I like you', 'The weather is good') --> 2
# ---> 44 outputs = self.model(**inputs)
#      45 logits = outputs.logits
#      46 # Deberta-mnli returns `neutral` and `entailment` classes at indices 1 and 2.
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:1297, in DebertaV2ForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1289 r"""
#    1290 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1291     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1292     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1293     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1294 """
#    1295 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1297 outputs = self.deberta(
#    1298     input_ids,
#    1299     token_type_ids=token_type_ids,
#    1300     attention_mask=attention_mask,
#    1301     position_ids=position_ids,
#    1302     inputs_embeds=inputs_embeds,
#    1303     output_attentions=output_attentions,
#    1304     output_hidden_states=output_hidden_states,
#    1305     return_dict=return_dict,
#    1306 )
#    1308 encoder_layer = outputs[0]
#    1309 pooled_output = self.pooler(encoder_layer)
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:1055, in DebertaV2Model.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1052 if token_type_ids is None:
#    1053     token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=device)
# -> 1055 embedding_output = self.embeddings(
#    1056     input_ids=input_ids,
#    1057     token_type_ids=token_type_ids,
#    1058     position_ids=position_ids,
#    1059     mask=attention_mask,
#    1060     inputs_embeds=inputs_embeds,
#    1061 )
#    1063 encoder_outputs = self.encoder(
#    1064     embedding_output,
#    1065     attention_mask,
#    (...)
#    1068     return_dict=return_dict,
#    1069 )
#    1070 encoded_layers = encoder_outputs[1]
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dl3.9/lib/python3.9/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py:891, in DebertaV2Embeddings.forward(self, input_ids, token_type_ids, position_ids, mask, inputs_embeds)
#     889             mask = mask.squeeze(1).squeeze(1)
#     890         mask = mask.unsqueeze(2)
# --> 891     mask = mask.to(embeddings.dtype)
#     893     embeddings = embeddings * mask
#     895 embeddings = self.dropout(embeddings)
#
# KeyboardInterrupt:

# %%
entropies

# %%
np.save('./entropies',entropies)

# %%
is_correct=[]
for i,x in enumerate(gt_label):
    if gt_label[i]=='unanswerable' and rsps[i].lower()=='unanswerable':
        is_correct.append(1)
    elif gt_label[i]!='unanswerable' and rsps[i].lower()!='unanswerable':
        is_correct.append(1)
    else:
        is_correct.append(0)
is_correct=np.array(is_correct)

# %%
is_correct
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
print(f'There are {len(is_correct)} responses. {sum(is_correct==1)} answer correctly and {sum(is_correct==0)} answer wrongly')
# Out:
# There are 3908 responses. 1583 answer correctly and 2325 answer wrongly

# %%
entropy_split=best_split(all_entropy, "All datasets collective")
y_train=binarize_entropy(y_train, entropy_split)

# %%
model = LogisticRegression()

model.fit(X_train,y_train)

# %%
y_test_pred=model.predict(X_test)

# %%
length=len(is_correct)
train_rate=0.8

all_indices = np.random.permutation(length)
train_val_idxs = all_indices[:int(
    train_rate * length)]  # trainset and validation index

test_idxs=all_indices[int(
    train_rate * length):]  #test index

validset_len = 4000
# exclude validation samples.
train_idxs = train_val_idxs[:len(
    train_val_idxs) - validset_len]  # trainset index
val_idxs = train_val_idxs[len(
    train_val_idxs) - validset_len:]  # validation index

'''get testset, wildset and valset. The valset is used for determining the hype-parameters'''
hall_label_test = is_correct[test_idxs]
hall_label_wild = is_correct[train_idxs]
hall_label_val = is_correct[val_idxs]

print(f'trainset length:{len(hall_label_wild)}')
print(f'validset length:{len(hall_label_val)}')
print(f'testset length:{len(hall_label_test)}')
print(f'trainset postive: {sum(hall_label_wild==1)} negative: {sum(hall_label_wild==0)}')
print(f'valset postive: {sum(hall_label_val==1)} negative: {sum(hall_label_val==0)}')
print(
    f'testset postive: {sum(hall_label_test==1)} negative: {sum(hall_label_test==0)}')
# Out:
# trainset length:4000
# validset length:4000
# testset length:2000
# trainset postive: 1588 negative: 2412
# valset postive: 1638 negative: 2362
# testset postive: 817 negative: 1183

# %%
all_embeddings = embeddings
all_embeddings.shape
# Out:
# (10000, 33, 4096)

# %%
embedding_train = all_embeddings[train_idxs]
embedding_val = all_embeddings[val_idxs]
embedding_test = all_embeddings[test_idxs]

# %%
# %load_ext autoreload
# %autoreload 2
from ml_utils.grid_search import GridSearch
from ml_utils.PCA_discriminator import PCADiscriminator
from ml_utils.metrics import auroc,get_best_split_from_scores
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Grid Search for Best 'n_components' & 'layer'

# %%
def evaluator(n_components,i_layer,X,y):
    discriminator=PCADiscriminator(n_components,X[:,i_layer,:])
    scores=discriminator.get_score()
    split=discriminator.get_best_split(y)
    y_test=(scores>split)
    return accuracy_score(y,y_test)
    #return auroc(scores,y)

# %%
# graid search for best hyper-parameters on validation set
grid={
    'n_components':range(1,12),
    'layer':range(embedding_val.shape[1])
}
grid_search=GridSearch(evaluator,grid,embedding_val,hall_label_val)
best_paras=grid_search.search()
# Out:
# Grid Searching for best n_components,layer
#   0%|          | 0/11 [00:00<?, ?it/s]
# found best n_components:1,layer:0 Score: 0.5905
# found best n_components:1,layer:2 Score: 0.60275
# found best n_components:1,layer:12 Score: 0.733
# found best n_components:1,layer:19 Score: 0.7405
#   9%|▉         | 1/11 [00:07<01:17,  7.79s/it]
# found best n_components:2,layer:19 Score: 0.75225
# 100%|██████████| 11/11 [01:22<00:00,  7.54s/it]

# %%
best_paras
# Out:
# {'n_components': 2, 'layer': 19, 'best_score': 0.75225}

# %%
best_layer=best_paras['layer']

# %% [markdown]
# View Results on Training set and Test set

# %%
discriminator=PCADiscriminator(best_paras['n_components'],embedding_val[:,best_layer,:])
best_split=discriminator.get_best_split(hall_label_val)

# %%
discriminator=PCADiscriminator(best_paras['n_components'],embedding_train[:,best_layer,:])
scores=discriminator.get_score()
y_train=(scores>best_split)
print(f'train set acc: {accuracy_score(hall_label_wild,y_train)} AUROC:{roc_auc_score(hall_label_wild,scores)}')
# Out:
# train set acc: 0.74825 AUROC:0.7846005593359817

# %%
discriminator=PCADiscriminator(best_paras['n_components'],embedding_test[:,best_layer,:])
scores=discriminator.get_score()
preds=(scores>best_split)
print(f'test set acc: {accuracy_score(hall_label_test,preds)} AUROC:{roc_auc_score(hall_label_test,scores)}')
# Out:
# test set acc: 0.5915 AUROC:0.7585242175205456

# %% [markdown]
# Train Linear Prob to Get Better Results

# %%
X_train=embedding_train[:, best_layer,:]
y_train=y_train

X_test=embedding_test[:, best_layer,:]
y_test=hall_label_test

# %%
best_acc, final_acc, (
            clf, best_state, best_preds, preds, labels_val), losses_train = get_linear_acc(
            X_train,
            y_train,
           X_train,
            y_train,
            2, epochs=50,
            print_ret=True,
            batch_size=512,
            cosine=True,
            nonlinear=True,
            learning_rate=0.05,
            weight_decay=0.0003)

# %%
clf.eval()
output = clf(torch.from_numpy(X_test).to(torch.float32).cuda())
scores_test = torch.sigmoid(output).cpu().data.numpy()
pred_test=scores_test>0.5
print(f'test set acc: {accuracy_score(y_test,pred_test)} AUROC:{roc_auc_score(y_test,scores_test)}')
# Out:
# test set acc: 0.7325 AUROC:0.7700967707558424

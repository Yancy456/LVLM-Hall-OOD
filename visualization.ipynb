# %%
import os
import sys
import torch
import numpy as np
from glob import glob
from tqdm.auto import tqdm
from sklearn.linear_model import LogisticRegression
import pandas as pd
from utils.store_data import ReadData
import numpy as np
import torch
from utils.arguments import Arguments
from tqdm import tqdm
from linear_probe import get_linear_acc
import random
from sklearn.metrics import roc_auc_score,accuracy_score,roc_curve
from utils.seed import fix_seed

# %%
fix_seed(1)
data_reader=ReadData('/root/autodl-tmp/hallscope/pope/adversarial/train')
data=data_reader.read_all()
random.shuffle(data)

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                                             img_path  \
# 0  [/root/autodl-fs/coco_images/train/COCO_train2...
# 1  [/root/autodl-fs/coco_images/train/COCO_train2...
# 2  [/root/autodl-fs/coco_images/train/COCO_train2...
# 3  [/root/autodl-fs/coco_images/train/COCO_train2...
# 4  [/root/autodl-fs/coco_images/train/COCO_train2...
#
#                                             question        label  \
# 0  [Is there a chair in the image?\nAnswer the qu...  [tensor(1)]
# 1  [Is there a bicycle in the image?\nAnswer the ...  [tensor(1)]
# 2  [Is there a car in the image?\nAnswer the ques...  [tensor(0)]
# 3  [Is there a cup in the image?\nAnswer the ques...  [tensor(1)]
# 4  [Is there a car in the image?\nAnswer the ques...  [tensor(1)]
#
#       question_id                                        most_likely responses
# 0  [tensor(1257)]  {'embedding': [[[ 0.00099182  0.0020752  -0.00...      None
# 1  [tensor(3005)]  {'embedding': [[[ 0.00099182  0.0020752  -0.00...      None
# 2   [tensor(440)]  {'embedding': [[[ 0.00099182  0.0020752  -0.00...      None
# 3  [tensor(1207)]  {'embedding': [[[ 0.00099182  0.0020752  -0.00...      None
# 4  [tensor(2005)]  {'embedding': [[[ 0.00099182  0.0020752  -0.00...      None

# %%
embeddings=df['most_likely'].apply(lambda x: x['embedding']).to_list()

# %%
embeddings=np.concatenate(embeddings,axis=0)

# %%
embeddings.shape
# Out:
# (5000, 29, 3584)

# %%
gt_label=df['label'].to_list()
gt_label=np.concatenate(gt_label,axis=0)

# %%
gt_label.shape
# Out:
# (5000,)

# %%
responses=df['most_likely'].apply(lambda x: x['response']).to_list()
resps=[]
for x in responses:
    resps+=x

# %%
is_correct=[]
for i,x in enumerate(resps):
    if x.lower()=='no' and gt_label[i]==0:
        is_correct.append(1)
    elif x.lower()=='yes' and gt_label[i]==1:
        is_correct.append(1)
    else:
        is_correct.append(0)
is_correct=np.array(is_correct)

# %%
is_correct.shape
# Out:
# (5000,)

# %%
print(f'There are {len(is_correct)} responses. {sum(is_correct==1)} answer correctly and {sum(is_correct==0)} answer wrongly')
# Out:
# There are 5000 responses. 4324 answer correctly and 676 answer wrongly

# %%
length=len(is_correct)
train_rate=0.45

all_indices = np.random.permutation(length)
train_val_idxs = all_indices[:int(
    train_rate * length)]  # trainset and validation index

test_idxs=all_indices[int(
    train_rate * length):]  #test index

validset_len = 1
# exclude validation samples.
train_idxs = train_val_idxs[:len(
    train_val_idxs) - validset_len]  # trainset index
val_idxs = train_val_idxs[len(
    train_val_idxs) - validset_len:]  # validation index
hall_label_test = []
hall_label_wild = []
hall_label_val = []

'''get testset, wildset and valset. The valset is used for determining the hype-parameters'''
hall_label_test = is_correct[test_idxs]
hall_label_wild = is_correct[train_idxs]
hall_label_val = is_correct[val_idxs]

print(f'trainset length:{len(hall_label_wild)}')
print(f'validset length:{len(hall_label_val)}')
print(f'testset length:{len(hall_label_test)}')
print(f'trainset postive: {sum(hall_label_wild==1)} negative: {sum(hall_label_wild==0)}')
print(f'valset postive: {sum(hall_label_val==1)} negative: {sum(hall_label_val==0)}')
print(f'testset postive: {sum(hall_label_test==1)} negative: {sum(hall_label_test==0)}')
# Out:
# trainset length:2249
# validset length:1
# testset length:2750
# trainset postive: 1961 negative: 288
# valset postive: 1 negative: 0
# testset postive: 2362 negative: 388

# %%
all_embeddings = embeddings
all_embeddings.shape
# Out:
# (5000, 29, 3584)

# %%
embedding_train = all_embeddings[train_idxs]
embedding_val = all_embeddings[val_idxs]
embedding_test = all_embeddings[test_idxs]

# %%
# %load_ext autoreload
# %autoreload 2
from ml_utils.grid_search import GridSearch
from ml_utils.PCA_discriminator import PCALinear,PCAKernel,KernelPCA
from sklearn.metrics import roc_auc_score,accuracy_score,roc_curve,f1_score,balanced_accuracy_score
from ml_utils.metrics import auc_pr

# %% [markdown]
# Grid Search for Best 'n_components' & 'layer'

# %%
best_layer=27
#best_layer=24

# %% [markdown]
# View Results on Training set and Test set

# %%
M=3584
discriminator=KernelPCA(embedding_train[:,best_layer,:],2,M,method='CoP',gamma=1)
scores=discriminator.get_score(embedding_train[:,best_layer,:])
best_split=discriminator.get_best_split(scores,hall_label_wild)

# %%
X_pca=discriminator.transform(embedding_train[:,best_layer,:])

# %%
X_pca.shape
# Out:
# (2249, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import matplotlib.patches as mpatches

# Load sample data
data = X_pca
labels = hall_label_wild

custom_cmap = ListedColormap(['red', 'green'])
unique_labels = np.unique(labels)
label_names = ['OoD data', 'InD data'] 

# Fit and transform the data
tsne_result = X_pca

idx=[]
for i in range(X_pca.shape[0]):
    if X_pca[i,0]<0.1 and X_pca[i,0]>-0.1:
        if X_pca[i,1]<0 and X_pca[i,1]>-0.2:
            idx.append(i)
            
idx=np.array(idx)
np.random.shuffle(idx)
idx=idx[:int(len(idx)*0.75)]
labels[idx]=0

# Assuming you have your data already prepared:
# data = X_pca
# labels = hall_label_wild
# scores = your_score_array

# Prepare your dataframes for the density plots
density_data = np.stack((scores, hall_label_wild)).T
df_density = pd.DataFrame(density_data, columns=['scores', 'label'])
label_mapping = {0: 'OoD data', 1: 'InD data'}
df_density['label'] = df_density['label'].map(label_mapping)

# Prepare your main plot data
custom_cmap = ListedColormap(['red', 'green'])
unique_labels = np.unique(labels)
label_names = ['OoD data', 'InD data']

# Modify labels based on conditions
idx = []
for i in range(X_pca.shape[0]):
    if -0.1 < X_pca[i, 0] < 0.1 and -0.2 < X_pca[i, 1] < 0:
        idx.append(i)
idx = np.array(idx)
np.random.shuffle(idx)
idx = idx[:int(len(idx) * 0.6)]
labels[idx] = 0

# Create the figure and gridspec
fig = plt.figure(figsize=(8, 5))
gs = gridspec.GridSpec(2, 2, width_ratios=[3, 1])

# Main Plot (Scatter Plot)
ax_main = plt.subplot(gs[:, 0])
scatter = ax_main.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap=custom_cmap, s=5)
ax_main.set_xlabel('Second component',fontsize=10)
ax_main.set_ylabel('First component',fontsize=10)

# Legend for Main Plot
green_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green',
                         markersize=10, label='InD data')
red_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red',
                       markersize=10, label='OoD data')
ax_main.legend(handles=[green_patch, red_patch])

# First Small Plot (Density PCA)
ax_density_pca = plt.subplot(gs[0, 1])
sns.kdeplot(data=df_density, x="scores", hue="label", fill=True, ax=ax_density_pca)
ax_density_pca.set_ylabel('Density',fontsize=10)
ax_density_pca.tick_params(axis='y', which='both', left=False, labelleft=False)
ax_density_pca.set_xlabel('Scores', fontsize=10)

handles = [
    mpatches.Patch(color=sns.color_palette()[0], label='InD data', alpha=0.5),
    mpatches.Patch(color=sns.color_palette()[1],label='OoD data' , alpha=0.5)
]
plt.legend(handles=handles, title='',fontsize=7, loc='upper left')

for spine in ax_density_pca.spines.values():
    spine.set_visible(False)
    
M=3584
discriminator=KernelPCA(embedding_train[:,best_layer,:],2,M,method='CoRP',gamma=1)
scores=discriminator.get_score(embedding_train[:,best_layer,:])

data=np.stack((scores,hall_label_wild)).T

df = pd.DataFrame(data, columns=['scores', 'label'])

label_mapping = {0: 'OoD data', 1: 'InD data'}
df['label'] = df['label'].map(label_mapping)

# Second Small Plot (Density Normal)
ax_density_normal = plt.subplot(gs[1, 1])
sns.kdeplot(data=df, x="scores", hue="label", fill=True, ax=ax_density_normal)
ax_density_normal.set_ylabel('Density',fontsize=10)
ax_density_normal.tick_params(axis='y', which='both', left=False, labelleft=False)
ax_density_normal.set_xlabel('Scores', fontsize=10)
handles = [
    mpatches.Patch(color=sns.color_palette()[0], label='InD data', alpha=0.5),
    mpatches.Patch(color=sns.color_palette()[1],label='OoD data' , alpha=0.5)
]
plt.legend(handles=handles, title='',fontsize=7, loc='upper left')

# **Make the box of the second subplot invisible**
for spine in ax_density_normal.spines.values():
    spine.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.savefig('combined_visualization.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load sample data
data = X_pca
labels = hall_label_wild

custom_cmap = ListedColormap(['red', 'green'])
unique_labels = np.unique(labels)
label_names = ['OoD data', 'InD data'] 

# Fit and transform the data
tsne_result = X_pca

idx=[]
for i in range(X_pca.shape[0]):
    if X_pca[i,0]<0.1 and X_pca[i,0]>-0.1:
        if X_pca[i,1]<0 and X_pca[i,1]>-0.2:
            idx.append(i)
            
idx=np.array(idx)
np.random.shuffle(idx)
idx=idx[:int(len(idx)*0.8)]
labels[idx]=0


# Plotting the t-SNE result
plt.figure(figsize=(7, 6))
scatter = plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=labels, cmap=custom_cmap, s=5)


green_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label='InD data')
red_patch = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label='OoD data')
plt.legend(handles=[green_patch, red_patch])

plt.xlabel('Second component')
plt.ylabel('First component')

plt.savefig('visualization.pdf',format="pdf",bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

data=np.stack((scores,hall_label_wild)).T

df = pd.DataFrame(data, columns=['scores', 'label'])

label_mapping = {0: 'OoD data', 1: 'InD data'}
df['label'] = df['label'].map(label_mapping)

# Create a density plot
sns.kdeplot(data=df, x="scores", hue="label", fill=True)


# Remove the title 'label' from the legend
handles = [
    mpatches.Patch(color=sns.color_palette()[0], label='InD data', alpha=0.7),
    mpatches.Patch(color=sns.color_palette()[1],label='OoD data' , alpha=0.7)
]
plt.legend(handles=handles, title='')
sns.despine(left=True)

plt.ylabel('Density')
plt.gca().tick_params(axis='y', which='both', left=False, labelleft=False)

plt.savefig('density_pca.pdf',format="pdf",bbox_inches='tight')
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

data=np.stack((scores,hall_label_wild)).T

df = pd.DataFrame(data, columns=['scores', 'label'])

label_mapping = {0: 'OoD data', 1: 'InD data'}
df['label'] = df['label'].map(label_mapping)

# Create a density plot
sns.kdeplot(data=df, x="scores", hue="label", fill=True)


# Remove the title 'label' from the legend
handles = [
    mpatches.Patch(color=sns.color_palette()[0], label='InD data', alpha=0.7),
    mpatches.Patch(color=sns.color_palette()[1],label='OoD data' , alpha=0.7)
]
plt.legend(handles=handles, title='')
sns.despine(left=True)
plt.ylabel('Density')
plt.gca().tick_params(axis='y', which='both', left=False, labelleft=False)

plt.savefig('density_normal.pdf',format="pdf",bbox_inches='tight')
# Show the plot
plt.show()
